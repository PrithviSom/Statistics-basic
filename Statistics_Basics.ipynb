# %% [markdown]
# 1.	What is the difference between descriptive statistics and inferential statistics? Explain with examples.

# %% [markdown]
#   - **Descriptive Statistics**:
# Descriptive statistics summarize and describe the main features of a dataset. They present information in a meaningful way through measures such as mean, median, mode, and standard deviation.
# Example:
# If a teacher calculates the average score of a class in an exam, that is descriptive statistics.
#
#  - **Inferential Statistics**:
# Inferential statistics involve using data from a sample to make predictions or generalizations about a population.
# Example:
# If we survey 100 students from a university and use that data to estimate the average GPA of all students, we are using inferential statistics.

# %% [markdown]
# 2.	What is sampling in statistics? Explain the differences between random and stratified sampling.

# %% [markdown]
#  - **Sampling**:
# Sampling is the process of selecting a subset of individuals or observations from a population to make statistical inferences about the entire population.
#
#  - **Random Sampling**:
# Each member of the population has an equal chance of being selected.
# Example: Selecting 50 students randomly from a university using a random number generator.
#
#  - **Stratified Sampling**:
# The population is divided into subgroups (strata) based on shared characteristics, and random samples are taken from each stratum.
# Example: Dividing students into groups by year (first, second, third) and selecting random samples from each group.

# %% [markdown]
# 3.	Define mean, median, and mode. Explain why these measures of central tendency are important.

# %% [markdown]
#  - **Mean**: The average value (sum of all values ÷ number of values).
#
#  - **Median**: The middle value when data is arranged in order.
#
#  - **Mode**: The most frequently occurring value.
#
#   **Importance**:
# These measures describe the central tendency, helping to summarize large datasets and understand where most data values lie.

# %% [markdown]
# 4.	Explain skewness and kurtosis. What does a positive skew imply about the data?

# %% [markdown]
#  - **Skewness**:
# It measures the asymmetry of a data distribution.
#
#  - Positive Skew: Tail is longer on the right side; most data values are concentrated on the left.
#
#  - Negative Skew: Tail is longer on the left side.
#
#  - **Kurtosis**:
# It measures the “tailedness” or peakedness of the distribution.
#
#  - High kurtosis: More outliers (heavy tails).
#
#  - Low kurtosis: Fewer outliers (light tails).

# %% [markdown]
# 5.	Implement a Python program to compute the mean, median, and mode of a given list of numbers.
# numbers = [12, 15, 12, 18, 19, 12, 20, 22, 19, 19, 24, 24, 24, 26, 28]

# %%
import statistics as stats

numbers = [12, 15, 12, 18, 19, 12, 20, 22, 19, 19, 24, 24, 24, 26, 28]

mean = stats.mean(numbers)
median = stats.median(numbers)
mode = stats.mode(numbers)

print("Mean:", mean)
print("Median:", median)
print("Mode:", mode)
# Out:
# Mean: 19.6
# Median: 19
# Mode: 12

# %% [markdown]
# 6.	Compute the covariance and correlation coefficient between the following two datasets provided as lists in Python:
#  list_x = [10, 20, 30, 40, 50]
#  list_y = [15, 25, 35, 45, 60]

# %%
import numpy as np

list_x = [10, 20, 30, 40, 50]
list_y = [15, 25, 35, 45, 60]

covariance = np.cov(list_x, list_y)[0, 1]
correlation = np.corrcoef(list_x, list_y)[0, 1]

print("Covariance:", covariance)
print("Correlation Coefficient:", correlation)
# Out:
# Covariance: 275.0
# Correlation Coefficient: 0.995893206467704

# %% [markdown]
# 7.	Write a Python script to draw a boxplot for the following numeric list and identify its outliers. Explain the result:
# data = [12, 14, 14, 15, 18, 19, 19, 21, 22, 22, 23, 23, 24, 26, 29, 35]

# %%
import matplotlib.pyplot as plt
import seaborn as sns

data = [12, 14, 14, 15, 18, 19, 19, 21, 22, 22, 23, 23, 24, 26, 29, 35]

sns.boxplot(data=data)
plt.title("Boxplot of Data")
plt.show()

# %% [markdown]
# 8.	You are working as a data analyst in an e-commerce company. The marketing team wants to know if there is a relationship between advertising spend and daily sales.
# Explain how you would use covariance and correlation to explore this relationship.
#  Write Python code to compute the correlation between the two lists:
#  advertising_spend = [200, 250, 300, 400, 500]
#  daily_sales = [2200, 2450, 2750, 3200, 4000]

# %%
import numpy as np

advertising_spend = [200, 250, 300, 400, 500]
daily_sales = [2200, 2450, 2750, 3200, 4000]

correlation = np.corrcoef(advertising_spend, daily_sales)[0, 1]
print("Correlation between advertising spend and sales:", correlation)
# Out:
# Correlation between advertising spend and sales: 0.9935824101653329

# %% [markdown]
# 9.	Your team has collected customer satisfaction survey data on a scale of 1-10 and wants to understand its distribution before launching a new product.
#   Explain which summary statistics and visualizations (e.g. mean, standard deviation, histogram) you’d use.
#  Write Python code to create a histogram using Matplotlib for the survey data: survey_scores = [7, 8, 5, 9, 6, 7, 8, 9, 10, 4, 7, 6, 9, 8, 7]

# %%
import matplotlib.pyplot as plt

survey_scores = [7, 8, 5, 9, 6, 7, 8, 9, 10, 4, 7, 6, 9, 8, 7]

plt.hist(survey_scores, bins=6, edgecolor='black')
plt.title("Customer Satisfaction Survey Distribution")
plt.xlabel("Scores")
plt.ylabel("Frequency")
plt.show()
